# %%
import graph_tool.all as gt                       # Biblioteca para GRAFO
import csv                                        # Biblioteca para Leitura do csv

g = gt.Graph() 
g.set_directed(False)                             # criação do objeto
v_name = g.new_vertex_property("string")          # referenciação da lista v_name com uma nova propriedade (label) criada para o vértice - tipo string  
v_pos  = g.new_vertex_property("vector<double>")
e_distance = g.new_edge_property("string") 
e_weight = g.new_edge_property("float")  
e_action = g.new_edge_property("string") 

#Criação dos vértices no grafo à partir do arquivo .csv de vértices
f_network = open("vertices.csv", 'r', encoding='utf-8')
reader_network = csv.reader(f_network, delimiter=",")

vposX = []
vposY = []
for vertice in reader_network:
    v = g.add_vertex()
    v_name[v] = str(vertice[1]) # Adicionando nome do vertice
    vposX.append(vertice[5]) # Adicionando posição X
    vposY.append(vertice[6]) # Adicionando posição Y
f_network.close()

#Criação das arestas no grafo à partir do arquivo .cvs de arestas
f_network = open("arestas.csv", 'r', encoding='utf-8')
reader_network = csv.reader(f_network, delimiter=",")
for edge in reader_network:
    e = g.add_edge(int(edge[0]), int(edge[1]))
    e_weight[e] = float(edge[2])
    print("pesos")
    print(e_weight[e])
    e_distance[e] = str(edge[3])
   
f_network.close()

#print("lista de peso")
#for a in e_weight:
#    print(a)

print(" > Lista de Transições: ",g.get_edges())


#Preenchendo as posições X e Y dos vértices
for v in g.vertices():
    v_pos[v] = (vposX[int(v)],vposY[int(v)])
    

gt.graph_draw(g, pos=v_pos, #pos=gt.arf_layout(visual_G),
               vertex_text= v_name,
               edge_text = e_weight,
               edge_pen_width = 5,  
               vertex_font_size=10,
               edge_font_size = 8,
               vertex_shape="circle",
               vertex_fill_color="#729fcf",
               output_size=(3000, 3000))
               #output="two-nodes.png")
# Out:
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
# pesos
# 1.0
#  > Lista de Transições:  [[ 0  1  0]
#  [ 1  2  1]
#  [ 1 49  2]
#  [ 2  3  3]
#  [ 3  4  4]
#  [ 3 45  5]
#  [ 4  5  6]
#  [ 5  6  7]
#  [ 6  7  8]
#  [ 6 44  9]
#  [ 7  8 10]
#  [ 8  9 11]
#  [ 8 44 12]
#  [ 9 10 13]
#  [ 9 53 14]
#  [10 11 15]
#  [10 56 16]
#  [11 12 17]
#  [11 57 18]
#  [12 13 19]
#  [12 58 20]
#  [13 14 21]
#  [14 15 22]
#  [15 16 23]
#  [16 17 24]
#  [17 18 25]
#  [18 19 26]
#  [19 20 27]
#  [20 21 28]
#  [21 22 29]
#  [22 23 30]
#  [22 60 31]
#  [23 24 32]
#  [24 25 33]
#  [25 26 34]
#  [26 27 35]
#  [27 28 36]
#  [27 48 37]
#  [28 29 38]
#  [29 30 39]
#  [29 48 40]
#  [30 31 41]
#  [31 32 42]
#  [32 33 43]
#  [32 47 44]
#  [33 34 45]
#  [33 46 46]
#  [34 35 47]
#  [35 36 48]
#  [36 37 49]
#  [36 46 50]
#  [37 38 51]
#  [37 52 52]
#  [38 39 53]
#  [38 51 54]
#  [39 40 55]
#  [39 49 56]
#  [40 41 57]
#  [41 42 58]
#  [41 45 59]
#  [42 43 60]
#  [43 44 61]
#  [43 53 62]
#  [44 45 63]
#  [46 47 64]
#  [47 48 65]
#  [49 50 66]
#  [50 51 67]
#  [51 52 68]
#  [53 54 69]
#  [54 55 70]
#  [55 56 71]
#  [56 57 72]
#  [57 58 73]
#  [58 59 74]
#  [59 60 75]]
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7fb29f18c8d0, at 0x7fb29f18c780>

# %%
import graph_tool.all as gt                           # Biblioteca para GRAFO
g_astar = gt.Graph()                                    # criação do objeto para busca em Largura
v_name_dfs = g_astar.new_vertex_property("string")      # referenciação da lista v_name com uma nova propriedade (label) criada para o vértice - tipo string 
e_ord = g_astar.new_edge_property("int")                # referenciação da lista e_ord com uma nova propriedade criada para a ordem de expansão - tipo int
e_action_bfs = g_astar.new_edge_property("string")
#def h(v):
#    return 
f_network = open("vertices.csv", 'r', encoding='utf-8')
reader_network = csv.reader(f_network, delimiter=",")
for vertice in reader_network:
    v = g_astar.add_vertex()
    v_name_dfs[v] = str(vertice[1])
f_network.close()

raiz = 'Porta'
index_raiz = list(v_name).index(raiz)
ord = 1

#print(index_raiz)
for edge in gt.astar_iterator(g, g.vertex(index_raiz), e_weight):
   #print(v_name[int(edge.source())], "->", v_name[int(edge.target())])
   e = g_astar.add_edge(int(edge.source()), int(edge.target()))
   e_ord[e] = ord
   e_action_bfs[e] = '(' + str(ord) + ') ' #+ e_action[g.edge(int(edge.source()), int(edge.target()))] 
   ord += 1

size = 5000
v_size = size / 50
e_pwidth = v_size / 8
gt.graph_draw(g_astar,#pos=gt.sfdp_layout(g_bfs),
              vertex_size = v_size,
              vertex_text= v_name_dfs,
              edge_text= e_ord,
              vertex_font_size=10,
              edge_font_size = 12,
              edge_pen_width = e_pwidth,
              vertex_shape="circle",
              vertex_fill_color="#729fcf",
              output_size=(size, size))
              #output="two-nodes.png")
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7fb29f0e1d68, at 0x7fb29f18cd30>

# %%
class VisitorExample(gt.AStarVisitor):                                            # É um objeto visitante que é chamado nos pontos de evento dentro do algoritmo bfs_search()
    def __init__(self, name, time, name_time, v_color, dist, pred, e_color, e_action, e_ord, target):
        self.name = name
        self.time = time
        self.name_time = name_time
        self.fill_color = v_color
        self.dist = dist
        self.pred = pred
        self.color = e_color
        self.e_action = e_action
        self.e_ord = e_ord
        self.e_count = 0
        self.last_time = 0
        self.target = target
        
    def discover_vertex(self, u):                                               # Invocado quando um vértice é encontrado pela primeira vez.
        self.name[u] = v_name[u]
        self.time[u] = self.last_time
        self.last_time += 1        
        self.name_time[u] = str(self.name[u]) + "(" + str(self.time[u]) + ")"
        print("-->", self.name[u], "foi encontrado e entrou na FILA") 
        self.fill_color[u] = "white"

    def examine_vertex(self, u):                                                # Invocado em um vértice à medida que é retirado da fila. 
        print("   ",self.name[u], "saiu da FILA e está sendo analisado (expandido)...") 

    def examine_edge(self, e):                                                  # Invocado em cada aresta de cada vértice depois de descoberto.
        print("    Aresta (%s, %s) em análise..." %               (v_name[e.source()], v_name[e.target()]))

    def edge_relaxed(self, e):                                                  #Após o exame do vértices, este método é invocado. 
        self.pred[e.target()] = int(e.source())                                 
        self.dist[e.target()] = self.dist[e.source()] + 1
        e = g_bfs.add_edge(int(e.source()), int(e.target()))
        self.color[e] = "gray"
        self.e_action[e] = e_action[g.edge(int(e.source()), int(e.target()))]
        self.e_count += 1
        self.e_ord[e] = self.e_count
        print("    Após análise, aresta (%s, %s) mantida." %             (v_name[e.source()], v_name[e.target()]))
       
    def finish_vertex(self, u):
        print("    > Todos os vértices adjacentes à", self.name[u], "foram descobertos!\n")

# %%
import graph_tool.all as gt  

g_astar = gt.Graph()                                      # criação do objeto para busca A Estrela
bfsv_name = g_astar.new_vertex_property("string")      # referenciação da lista v_name_bfs com uma nova propriedade do vértice para o nome - tipo string 
bfsv_time = g_astar.new_vertex_property("int")         # referenciação da lista v_time com uma nova propriedade do vértice para a ordem de expansão - tipo int
bfsv_name_time = g_astar.new_vertex_property("string")      # referenciação da lista v_name_time com uma nova propriedade do vértice para o nome e ordem de expansão - tipo string
bfsv_color = g_astar.new_vertex_property("string")      # referenciação da lista v_color com uma nova propriedade do vértice para a cor - tipo string  
bfsv_dist = g_astar.new_vertex_property("int")         # referenciação da lista v_dist como uma propriedade do vértice criada para a distância da raiz
bfsv_pred = g_astar.new_vertex_property("int64_t")     # referenciação da lista v_pred como uma propriedade do vértice para referenciar o predecessor (pai)
bfse_color = g_astar.new_edge_property("string")        # referenciação da lista e_color com uma nova propriedade da aresta para a cor - tipo string  
bfse_action = g_astar.new_edge_property("string")        # referenciação da lista e_action_bfs com uma nova propriedade da aresta para a ação - tipo string
bfse_ord = g_astar.new_edge_property("string")        # referenciação da lista e_action_bfs com uma nova propriedade da aresta para a ação - tipo string
bfse_weight_bfs = g_astar.new_edge_property("float")       # referenciação da lista e_weight com uma nova propriedade criada para a função g(n) - tipo float

raiz = 'Porta'
alvo = 'Americanas'
index_raiz = list(v_name).index(raiz)
index_alvo = list(v_name).index(alvo) 

print(list(v_name).index(alvo))
gt.astar_search(g, g.vertex(index_raiz), e_weight, VisitorExample(bfsv_name, bfsv_time, bfsv_name_time, bfsv_color, 
                                    bfsv_dist, bfsv_pred, bfse_color, bfse_action, bfse_ord, g.vertex(index_alvo)))

#print(list(bfsv_name).index(alvo))
print(list(bfsv_name)) #nao ta retornando para a lista
# Out:
# 29
# --> Porta foi encontrado e entrou na FILA
#     Porta saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Porta, #) em análise...
#     Após análise, aresta (Porta, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Porta foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Unique) em análise...
#     Após análise, aresta (#, Unique) mantida.
# --> Unique foi encontrado e entrou na FILA
#     Aresta (#, Apple) em análise...
#     Após análise, aresta (#, Apple) mantida.
# --> Apple foi encontrado e entrou na FILA
#     Aresta (#, Porta) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Unique saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Unique, Lojas Brasil) em análise...
#     Após análise, aresta (Unique, Lojas Brasil) mantida.
# --> Lojas Brasil foi encontrado e entrou na FILA
#     Aresta (Unique, #) em análise...
#     > Todos os vértices adjacentes à Unique foram descobertos!
#
#     Apple saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Apple, Sky) em análise...
#     Após análise, aresta (Apple, Sky) mantida.
# --> Sky foi encontrado e entrou na FILA
#     Aresta (Apple, Hoyoverse) em análise...
#     Após análise, aresta (Apple, Hoyoverse) mantida.
# --> Hoyoverse foi encontrado e entrou na FILA
#     Aresta (Apple, #) em análise...
#     > Todos os vértices adjacentes à Apple foram descobertos!
#
#     Lojas Brasil saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Lojas Brasil, #) em análise...
#     Após análise, aresta (Lojas Brasil, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (Lojas Brasil, #) em análise...
#     Após análise, aresta (Lojas Brasil, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (Lojas Brasil, Unique) em análise...
#     > Todos os vértices adjacentes à Lojas Brasil foram descobertos!
#
#     Hoyoverse saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Hoyoverse, Asus) em análise...
#     Após análise, aresta (Hoyoverse, Asus) mantida.
# --> Asus foi encontrado e entrou na FILA
#     Aresta (Hoyoverse, Apple) em análise...
#     Aresta (Hoyoverse, #) em análise...
#     Após análise, aresta (Hoyoverse, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Hoyoverse foram descobertos!
#
#     Sky saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Sky, Logitech) em análise...
#     Após análise, aresta (Sky, Logitech) mantida.
# --> Logitech foi encontrado e entrou na FILA
#     Aresta (Sky, Apple) em análise...
#     > Todos os vértices adjacentes à Sky foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Hoyoverse) em análise...
#     Aresta (#, Logitech) em análise...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Logitech saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Logitech, Musicyan) em análise...
#     Após análise, aresta (Logitech, Musicyan) mantida.
# --> Musicyan foi encontrado e entrou na FILA
#     Aresta (Logitech, Sky) em análise...
#     Aresta (Logitech, #) em análise...
#     > Todos os vértices adjacentes à Logitech foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Lojas Brasil) em análise...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, Lojas Brasil) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Asus saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Asus, #) em análise...
#     Aresta (Asus, Hoyoverse) em análise...
#     > Todos os vértices adjacentes à Asus foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Cacau Show) em análise...
#     Após análise, aresta (#, Cacau Show) mantida.
# --> Cacau Show foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Evolution) em análise...
#     Após análise, aresta (#, Evolution) mantida.
# --> Evolution foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     Aresta (#, Asus) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Aresta (#, Musicyan) em análise...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Musicyan saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Musicyan, #) em análise...
#     Aresta (Musicyan, Logitech) em análise...
#     > Todos os vértices adjacentes à Musicyan foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, Motorola) em análise...
#     Após análise, aresta (#, Motorola) mantida.
# --> Motorola foi encontrado e entrou na FILA
#     Aresta (#, Cacau Show) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Aresta (#, Renner) em análise...
#     Após análise, aresta (#, Renner) mantida.
# --> Renner foi encontrado e entrou na FILA
#     Aresta (#, Golden Fitness) em análise...
#     Após análise, aresta (#, Golden Fitness) mantida.
# --> Golden Fitness foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Motorola saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Motorola, #) em análise...
#     Aresta (Motorola, Xiaomi) em análise...
#     Após análise, aresta (Motorola, Xiaomi) mantida.
# --> Xiaomi foi encontrado e entrou na FILA
#     Aresta (Motorola, Evolution) em análise...
#     > Todos os vértices adjacentes à Motorola foram descobertos!
#
#     Cacau Show saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Cacau Show, Samsung) em análise...
#     Após análise, aresta (Cacau Show, Samsung) mantida.
# --> Samsung foi encontrado e entrou na FILA
#     Aresta (Cacau Show, #) em análise...
#     Aresta (Cacau Show, #) em análise...
#     > Todos os vértices adjacentes à Cacau Show foram descobertos!
#
#     Evolution saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Evolution, Motorola) em análise...
#     Aresta (Evolution, #) em análise...
#     > Todos os vértices adjacentes à Evolution foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, JBL) em análise...
#     Após análise, aresta (#, JBL) mantida.
# --> JBL foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     Aresta (#, Samsung) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Renner saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Renner, Riachuelo) em análise...
#     Após análise, aresta (Renner, Riachuelo) mantida.
# --> Riachuelo foi encontrado e entrou na FILA
#     Aresta (Renner, #) em análise...
#     Aresta (Renner, Riot Games) em análise...
#     Após análise, aresta (Renner, Riot Games) mantida.
# --> Riot Games foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Renner foram descobertos!
#
#     JBL saiu da FILA e está sendo analisado (expandido)...
#     Aresta (JBL, Huawei) em análise...
#     Após análise, aresta (JBL, Huawei) mantida.
# --> Huawei foi encontrado e entrou na FILA
#     Aresta (JBL, Xiaomi) em análise...
#     Aresta (JBL, #) em análise...
#     > Todos os vértices adjacentes à JBL foram descobertos!
#
#     Golden Fitness saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Golden Fitness, #) em análise...
#     Aresta (Golden Fitness, My Drunks) em análise...
#     Após análise, aresta (Golden Fitness, My Drunks) mantida.
# --> My Drunks foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Golden Fitness foram descobertos!
#
#     Xiaomi saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Xiaomi, Conecta Imports) em análise...
#     Após análise, aresta (Xiaomi, Conecta Imports) mantida.
# --> Conecta Imports foi encontrado e entrou na FILA
#     Aresta (Xiaomi, Motorola) em análise...
#     Aresta (Xiaomi, JBL) em análise...
#     > Todos os vértices adjacentes à Xiaomi foram descobertos!
#
#     Samsung saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Samsung, #) em análise...
#     Aresta (Samsung, Cacau Show) em análise...
#     > Todos os vértices adjacentes à Samsung foram descobertos!
#
#     Conecta Imports saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Conecta Imports, LG) em análise...
#     Após análise, aresta (Conecta Imports, LG) mantida.
# --> LG foi encontrado e entrou na FILA
#     Aresta (Conecta Imports, Xiaomi) em análise...
#     > Todos os vértices adjacentes à Conecta Imports foram descobertos!
#
#     Riachuelo saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Riachuelo, #) em análise...
#     Após análise, aresta (Riachuelo, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (Riachuelo, Renner) em análise...
#     Aresta (Riachuelo, ItatechJr) em análise...
#     Após análise, aresta (Riachuelo, ItatechJr) mantida.
# --> ItatechJr foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Riachuelo foram descobertos!
#
#     Riot Games saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Riot Games, My Drunks) em análise...
#     Aresta (Riot Games, Renner) em análise...
#     Aresta (Riot Games, ItatechJr) em análise...
#     > Todos os vértices adjacentes à Riot Games foram descobertos!
#
#     Huawei saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Huawei, TPLINK) em análise...
#     Após análise, aresta (Huawei, TPLINK) mantida.
# --> TPLINK foi encontrado e entrou na FILA
#     Aresta (Huawei, Pingo de Ouro) em análise...
#     Após análise, aresta (Huawei, Pingo de Ouro) mantida.
# --> Pingo de Ouro foi encontrado e entrou na FILA
#     Aresta (Huawei, JBL) em análise...
#     > Todos os vértices adjacentes à Huawei foram descobertos!
#
#     My Drunks saiu da FILA e está sendo analisado (expandido)...
#     Aresta (My Drunks, Golden Fitness) em análise...
#     Aresta (My Drunks, Riot Games) em análise...
#     > Todos os vértices adjacentes à My Drunks foram descobertos!
#
#     Pingo de Ouro saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Pingo de Ouro, Yamaha) em análise...
#     Após análise, aresta (Pingo de Ouro, Yamaha) mantida.
# --> Yamaha foi encontrado e entrou na FILA
#     Aresta (Pingo de Ouro, LG) em análise...
#     Aresta (Pingo de Ouro, Huawei) em análise...
#     > Todos os vértices adjacentes à Pingo de Ouro foram descobertos!
#
#     TPLINK saiu da FILA e está sendo analisado (expandido)...
#     Aresta (TPLINK, #) em análise...
#     Após análise, aresta (TPLINK, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (TPLINK, Yamaha) em análise...
#     Aresta (TPLINK, Huawei) em análise...
#     > Todos os vértices adjacentes à TPLINK foram descobertos!
#
#     LG saiu da FILA e está sendo analisado (expandido)...
#     Aresta (LG, Pingo de Ouro) em análise...
#     Aresta (LG, Conecta Imports) em análise...
#     > Todos os vértices adjacentes à LG foram descobertos!
#
#     ItatechJr saiu da FILA e está sendo analisado (expandido)...
#     Aresta (ItatechJr, Riot Games) em análise...
#     Aresta (ItatechJr, Riachuelo) em análise...
#     Aresta (ItatechJr, Joalheira Pérola) em análise...
#     Após análise, aresta (ItatechJr, Joalheira Pérola) mantida.
# --> Joalheira Pérola foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à ItatechJr foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Jesus High Tech) em análise...
#     Após análise, aresta (#, Jesus High Tech) mantida.
# --> Jesus High Tech foi encontrado e entrou na FILA
#     Aresta (#, Americanas) em análise...
#     Após análise, aresta (#, Americanas) mantida.
# --> Americanas foi encontrado e entrou na FILA
#     Aresta (#, Riachuelo) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Joalheira Pérola saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Joalheira Pérola, ItatechJr) em análise...
#     Aresta (Joalheira Pérola, Magazine Luiza) em análise...
#     Após análise, aresta (Joalheira Pérola, Magazine Luiza) mantida.
# --> Magazine Luiza foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Joalheira Pérola foram descobertos!
#
#     Americanas saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Americanas, Magazine Luiza) em análise...
#     Aresta (Americanas, #) em análise...
#     Aresta (Americanas, Estrijoias) em análise...
#     Após análise, aresta (Americanas, Estrijoias) mantida.
# --> Estrijoias foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Americanas foram descobertos!
#
#     Yamaha saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Yamaha, #) em análise...
#     Após análise, aresta (Yamaha, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (Yamaha, Pingo de Ouro) em análise...
#     Aresta (Yamaha, TPLINK) em análise...
#     > Todos os vértices adjacentes à Yamaha foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Cinema) em análise...
#     Após análise, aresta (#, Cinema) mantida.
# --> Cinema foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     Aresta (#, TPLINK) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Jesus High Tech saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Jesus High Tech, Estrijoias) em análise...
#     Aresta (Jesus High Tech, #) em análise...
#     Aresta (Jesus High Tech, Cooler Master) em análise...
#     Após análise, aresta (Jesus High Tech, Cooler Master) mantida.
# --> Cooler Master foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Jesus High Tech foram descobertos!
#
#     Cinema saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Cinema, #) em análise...
#     Após análise, aresta (Cinema, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (Cinema, #) em análise...
#     > Todos os vértices adjacentes à Cinema foram descobertos!
#
#     Cooler Master saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Cooler Master, Jesus High Tech) em análise...
#     Aresta (Cooler Master, #) em análise...
#     Após análise, aresta (Cooler Master, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Cooler Master foram descobertos!
#
#     Magazine Luiza saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Magazine Luiza, Joalheira Pérola) em análise...
#     Aresta (Magazine Luiza, Americanas) em análise...
#     > Todos os vértices adjacentes à Magazine Luiza foram descobertos!
#
#     Estrijoias saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Estrijoias, Americanas) em análise...
#     Aresta (Estrijoias, Jesus High Tech) em análise...
#     > Todos os vértices adjacentes à Estrijoias foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, Yamaha) em análise...
#     Aresta (#, #) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Cooler Master) em análise...
#     Aresta (#, Honda) em análise...
#     Após análise, aresta (#, Honda) mantida.
# --> Honda foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, Kei) em análise...
#     Após análise, aresta (#, Kei) mantida.
# --> Kei foi encontrado e entrou na FILA
#     Aresta (#, Cinema) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     Aresta (#, #) em análise...
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Kei saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Kei, OnePlus) em análise...
#     Após análise, aresta (Kei, OnePlus) mantida.
# --> OnePlus foi encontrado e entrou na FILA
#     Aresta (Kei, #) em análise...
#     > Todos os vértices adjacentes à Kei foram descobertos!
#
#     Honda saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Honda, #) em análise...
#     Aresta (Honda, POP) em análise...
#     Após análise, aresta (Honda, POP) mantida.
# --> POP foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à Honda foram descobertos!
#
#     OnePlus saiu da FILA e está sendo analisado (expandido)...
#     Aresta (OnePlus, Galego Do Peixe) em análise...
#     Após análise, aresta (OnePlus, Galego Do Peixe) mantida.
# --> Galego Do Peixe foi encontrado e entrou na FILA
#     Aresta (OnePlus, Kei) em análise...
#     > Todos os vértices adjacentes à OnePlus foram descobertos!
#
#     POP saiu da FILA e está sendo analisado (expandido)...
#     Aresta (POP, Honda) em análise...
#     Aresta (POP, #) em análise...
#     > Todos os vértices adjacentes à POP foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, POP) em análise...
#     Aresta (#, #) em análise...
#     Aresta (#, #) em análise...
#     Após análise, aresta (#, #) mantida.
# --> # foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Galego Do Peixe saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Galego Do Peixe, Steak House) em análise...
#     Após análise, aresta (Galego Do Peixe, Steak House) mantida.
# --> Steak House foi encontrado e entrou na FILA
#     Aresta (Galego Do Peixe, OnePlus) em análise...
#     > Todos os vértices adjacentes à Galego Do Peixe foram descobertos!
#
#     # saiu da FILA e está sendo analisado (expandido)...
#     Aresta (#, #) em análise...
#     Aresta (#, Mc Donalds) em análise...
#     Após análise, aresta (#, Mc Donalds) mantida.
# --> Mc Donalds foi encontrado e entrou na FILA
#     > Todos os vértices adjacentes à # foram descobertos!
#
#     Steak House saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Steak House, BK) em análise...
#     Após análise, aresta (Steak House, BK) mantida.
# --> BK foi encontrado e entrou na FILA
#     Aresta (Steak House, Galego Do Peixe) em análise...
#     > Todos os vértices adjacentes à Steak House foram descobertos!
#
#     Mc Donalds saiu da FILA e está sendo analisado (expandido)...
#     Aresta (Mc Donalds, #) em análise...
#     Aresta (Mc Donalds, BK) em análise...
#     > Todos os vértices adjacentes à Mc Donalds foram descobertos!
#
#     BK saiu da FILA e está sendo analisado (expandido)...
#     Aresta (BK, Mc Donalds) em análise...
#     Aresta (BK, Steak House) em análise...
#     > Todos os vértices adjacentes à BK foram descobertos!
#
# []
